# %%
from google import genai

client = genai.Client(api_key="AIzaSyA8HKbAXWjvh_cKQ8ynbyXztw6zIczelGk")

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="what is the last version of iphon mobile"
)
print(response.text)
# Out:
# As of my last update, and considering the typical annual release cycle, the latest version of the iPhone is the **iPhone 15 series**.
#
# This series was released in September 2023 and includes:
#
# *   **iPhone 15**
# *   **iPhone 15 Plus**
# *   **iPhone 15 Pro**
# *   **iPhone 15 Pro Max**
#
# Apple typically releases new iPhone models in the fall (September) each year, so the next generation (likely the iPhone 16 series) is expected around September 2024.
